# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# %%
plt.plot(x, y)
plt.title("line graph") ##グラフのタイトル
plt.xlabel("x") ##x軸のラベル
plt.ylabel("y") ##y軸のラベル
plt.show() ##グラフを表示(省略可)
